# %%
from langgraph.graph import END, START, StateGraph
from langchain_ollama import ChatOllama
from typing import TypedDict

# %%
model = ChatOllama(
    model="llama3.2:3b",    
    temperature=0.7
)

# %%
#create state
class BlogState(TypedDict):

    title:str
    outline:str
    content:str
    score : int

# %%
def create_outline(state: BlogState) -> BlogState:

    #fetch title
    title = state["title"]
    #call llm and generate outline
    prompt = f"""
    Generate an outline for a blog post with the title: {title}
    """
    outline = model.invoke(prompt).content
    #store outline in state
    state["outline"] = outline
    return {
        **state,
        "outline": outline
    }

# %%
def create_blog(state: BlogState) -> BlogState:
    
    #fetch title and currrnet outline
    title = state["title"]
    outline = state["outline"]

    #prompt
    prompt = f"""
    Generate a detailed blog on the title-{title} and outline-{outline}
    """
    content = model.invoke(prompt).content
    
    #store content in state
    state["content"] = content
    return {
        **state,
        "content": content
    }

# %%
def evaluate_blog(state : BlogState) -> BlogState:

    #fetch the outlinne and geerate scrore using prompt ad llm nd strore in state
    outline = state["outline"]

    prompt = f"""
    Based on the outline, evaluate the blog post for {outline}.
    Provide a score between 0 and 100, where 100 is the highest quality.
    """

    score = model.invoke(prompt).content
    state["score"] = score
    return {
        **state,
        "score" : score
    }

# %%
#create graph
graph = StateGraph(BlogState)

#add node
graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)
graph.add_node("evaluate_blog", evaluate_blog)

#add edges
graph.add_edge(START,"create_outline")
graph.add_edge("create_outline", "create_blog")
graph.add_edge("create_blog", "evaluate_blog")
graph.add_edge("evaluate_blog", END)

workflow = graph.compile()

# %%
initial_state = {"title": "Rise of AI in India"}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here is a potential outline for a blog post on "The Rise of AI in India":\n\n**I. Introduction**\n\n* Brief overview of the growth of Artificial Intelligence (AI) globally and its increasing presence in India\n* Importance of understanding the rise of AI in India, its impact on businesses and society, and future prospects\n\n**II. Background: AI Adoption in India**\n\n* Overview of the history of AI adoption in India, from early initiatives to current developments\n* Discussion of government initiatives and funding for AI research and development in India\n* Statistics on AI adoption rates in India compared to other countries\n\n**III. Key Areas of AI Adoption in India**\n\n* **Healthcare**: Use of AI in medical diagnosis, disease prediction, and personalized medicine\n* **Financial Services**: Application of AI in risk management, credit scoring, and customer service\n* **Education**: Use of AI-powered adaptive learning systems and chatbots for student support\n* **Manufacturing and Logistics**: Implementation of AI in predictive maintenance, supply chain optimization, and quality control\n\n**IV. Indian Startups Leading the AI Charge**\n\n* Overview of some of the most promising Indian startups working on AI-related projects\n* Case studies of successful AI-powered products or services from these startups\n* Discussion of funding and investment trends for AI startups in India\n\n**V. Challenges and Opportunities**\n\n* Discussion of challenges faced by businesses and individuals in adopting AI, such as data quality issues and talent shortages\n* Overview of opportunities presented by AI adoption in India, including job creation, economic growth, and improved customer experiences\n\n**VI. Future Outlook: The Role of AI in Shaping India\'s Economy and Society**\n\n* Discussion of the long-term potential of AI to transform India\'s economy and society\n* Potential applications of AI in areas like sustainable energy, smart cities, and digital governance\n* Conclusion on the importance of continued investment and innovation in AI research and development in India.\n\nThis outline provides a general structure for exploring the rise of AI in India, covering topics from government initiatives to startup success stories.', 'content': "**The Rise of AI in India: A Comprehensive Overview**\n\nIndia has emerged as a significant player in the global Artificial Intelligence (AI) landscape, with the technology sector growing at an unprecedented rate. The Indian government's strategic focus on AI development and adoption has been instrumental in fostering this growth. In this blog post, we will delve into the world of AI in India, exploring its background, key applications, startup success stories, challenges, and future prospects.\n\n**Introduction**\n\nThe global AI market is projected to reach $190 billion by 2025, with India expected to contribute significantly to this growth (Source: MarketsandMarkets). With a large and growing pool of skilled IT professionals, a favorable business environment, and government support, India has become an attractive destination for AI adoption. The rise of AI in India holds significant promise for businesses, policymakers, and individuals alike.\n\n**Background: AI Adoption in India**\n\nThe history of AI adoption in India dates back to the 1980s, with the establishment of the Indian Institute of Technology (IIT) Bombay's Artificial Intelligence Laboratory. Over the years, various government initiatives have been launched to promote AI development and adoption, including:\n\n1. **National Programme on Artificial Intelligence (NPAI)**: Launched in 2017, this program aims to promote AI research and development in India.\n2. **Atal Innovation Mission (AIM)**: Announced in 2020, AIM aims to foster innovation and entrepreneurship in AI and other emerging technologies.\n\n**Statistics on AI Adoption Rates**\n\nIndia's AI adoption rate is growing rapidly, with:\n\n1 ...

# %%
print(final_state["score"])
# Out:
# Based on the provided outline, I would give this blog post an score of 85 out of 100.
#
# Here's why:
#
# **Strengths:**
#
# 1. Comprehensive structure: The outline covers a wide range of topics related to AI in India, from background and adoption rates to specific applications and future outlook.
# 2. Balanced approach: The outline strikes a good balance between covering the technical aspects of AI, its impact on businesses and society, and the role of Indian startups and government initiatives.
# 3. Clear organization: The six sections clearly outline the scope of the blog post, making it easy for readers to follow along.
#
# **Weaknesses:**
#
# 1. Lack of specificity: Some sections, such as "Key Areas of AI Adoption in India," feel a bit broad and lack specific examples or case studies.
# 2. Overemphasis on government initiatives: While government support for AI is important, the outline could benefit from more focus on the private sector's role in driving AI adoption and innovation.
# 3. Limited depth: Given the scope of the blog post, some topics may not receive sufficient attention or analysis.
#
# **Suggestions for improvement:**
#
# 1. Add more specific examples and case studies to illustrate key points, especially in "Key Areas of AI Adoption in India."
# 2. Include more nuanced discussions on the challenges and opportunities associated with AI adoption in India.
# 3. Consider adding a section on ethics and regulation in AI, given growing concerns about bias and accountability in AI applications.
#
# Overall, this outline provides a solid foundation for a comprehensive blog post on the rise of AI in India. With some further development and refinement, it has the potential to become an excellent resource for readers interested in this topic.

# %%
print(final_state["content"])
# Out:
# **The Rise of AI in India: Transforming Industries, Revolutionizing Business Models, and Unlocking New Opportunities**
#
# Introduction:
#
# Artificial Intelligence (AI) has been gaining momentum globally, with its applications expanding into various industries. Given India's strategic location and growing economy, the rise of AI in India is particularly noteworthy. This blog post aims to explore the current state of AI in India, key drivers of adoption, industry applications, challenges, and opportunities.
#
# **I. Introduction**
#
# Artificial Intelligence (AI) has become an essential aspect of modern business, transforming industries and revolutionizing business models worldwide. With its increasing importance globally, understanding the rise of AI in India is crucial for businesses, policymakers, and individuals alike. This post will delve into the current state of AI in India, key drivers of adoption, industry applications, challenges, and opportunities.
#
# **II. Current State of AI in India**
#
# The Indian government has been actively promoting AI adoption through various initiatives, such as the National Artificial Intelligence Mission (NAIM), the AI for Social Impact (ASI) initiative, and the Digital India program. Major players like Google, Microsoft, Amazon, and IBM have established significant presence in India, driving innovation and collaboration. Startups like Haptik, Ather Energy, and Innoviti Technologies are also leading the charge in AI adoption.
#
# Government initiatives and regulations supporting AI growth include:
#
# 1. The Data Protection Act, 2018, which aims to protect personal data and ensure its safe handling.
# 2. The IT Act, 2000, which provides a framework for AI development and deployment.
# 3. The NAIM initiative, which focuses on developing AI capabilities and applications in various sectors.
#
# Current applications of AI in India include:
#
# 1. Chatbots and virtual assistants
# 2. Medical diagnosis and personalized medicine
# 3. Risk assessment and portfolio management in finance
# 4. Adaptive learning platforms and personalized education
#
# **III. Key Drivers of AI Adoption in India**
#
# Several factors are driving the adoption of AI in India, including:
#
# 1. **Economic growth and urbanization**: As India's economy grows, there is an increasing demand for data-driven decision-making, which AI can provide.
# 2. **Government initiatives and policies supporting AI development**: Government initiatives like NAIM and ASI have created a conducive environment for AI adoption.
# 3. **Increasing availability of affordable computing resources**: Cloud services and open-source software are making AI more accessible to businesses and startups.
# 4. **Growing demand for data-driven decision-making**: Businesses in India are recognizing the importance of data analysis and AI-powered insights.
#
# **IV. Industry Applications of AI in India**
#
# AI is being increasingly applied across various industries, including:
#
# 1. **Healthcare**:
# 	* Chatbots for patient engagement and support
# 	* Medical diagnosis using machine learning algorithms
# 	* Personalized medicine through genomics and precision healthcare
# 2. **Finance**:
# 	* Risk assessment and portfolio management using AI-powered tools
# 	* Credit scoring and lending analytics
# 	* Anti-money laundering (AML) and know-your-customer (KYC)
# 3. **Education**:
# 	* Adaptive learning platforms for personalized education
# 	* Automated grading and feedback systems
# 	* AI-powered tutoring and mentoring
# 4. **Manufacturing**:
# 	* Predictive maintenance using machine learning algorithms
# 	* Quality control and supply chain optimization
# 	* Predictive analytics for demand forecasting and inventory management
#
# **V. Challenges and Opportunities**
#
# While AI adoption in India is growing, several challenges need to be addressed:
#
# 1. **Data quality and availability issues**: High-quality data is essential for effective AI applications, but data availability and quality can be a challenge.
# 2. **Talent acquisition and retention difficulties**: The Indian tech industry faces talent shortages, particularly in areas like machine learning engineering.
# 3. **Regulatory frameworks and data privacy concerns**: India's regulatory landscape is evolving to address AI adoption, with a focus on data privacy and security.
#
# Opportunities for growth and innovation in AI-enabled industries include:
#
# 1. **AI-powered startups**: The Indian startup ecosystem has seen significant growth in AI-powered ventures, with potential for scalability and global impact.
# 2. **Research collaborations**: Collaboration between Indian research institutions, academia, and industry players can lead to breakthroughs in AI development and application.
# 3. **Skill development programs**: Governments and industries can invest in skill development programs to address talent shortages and upskill existing workforce.
#
# **VI. Conclusion**
#
# The rise of AI in India is transforming industries, revolutionizing business models, and creating new opportunities for growth and innovation. As the country continues to grow and evolve, it's essential to understand the current state of AI adoption, key drivers, industry applications, challenges, and opportunities. By addressing these factors, India can unlock its full potential as a global leader in AI adoption and development.
#
# **Future Outlook**
#
# Predictions for AI adoption in India include:
#
# 1. **Increased investment in AI startups**: The Indian government and private investors are expected to increase investments in AI-powered startups.
# 2. **Growing demand for AI talent**: The Indian tech industry will require more skilled professionals, including machine learning engineers, data scientists, and AI researchers.
# 3. **AI-powered services adoption**: Expect increased adoption of AI-powered services across industries, including healthcare, finance, education, and manufacturing.
#
# As India continues to navigate the AI landscape, it's crucial to stay informed about the latest developments, trends, and opportunities in AI adoption. By understanding the rise of AI in India, businesses, policymakers, and individuals can unlock new growth potential and contribute to the country's emergence as a global leader in AI development and adoption.
